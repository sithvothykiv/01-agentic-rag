# %%
# !ls
# Out:
# __pycache__                 persinsent_rag.ipynb
# agents.ipynb                persistent_rag_ingest.ipynb
# ingest.py                   pyproject.toml
# notebook_copy.ipynb         rag_cleaned.ipynb
# notebook.ipynb              rag_helper.py

# %%
# !pwd
# Out:
# /Users/kivsithvothy/Downloads/llm-zoomcamp/01-agentic-rag/code

# %%
# import sys
# import os
# from pathlib import Path

# # Resolve target directory
# target_path = Path('./01-agentic-rag/code').resolve()
# if not target_path.exists():
#     target_path = Path('.').resolve()

# if str(target_path) not in sys.path:
#     sys.path.append(str(target_path))

# os.chdir(target_path)


from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
# %pip install minsearch

# %%
# %pip install dotenv

# %%
# %pip install openai

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
print(os.getenv("GROQ_API_KEY"))

# %%
from openai import OpenAI
openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# 'Yes—you can still join the course. If you want to earn a certificate, just make sure you submit your capstone project while the submission form is still open.'
